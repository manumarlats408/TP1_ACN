# %%
from main import Simulador

lam = 1  # forzar muchísimos arribos
sim = Simulador(seed=42)
sim.simular_dia(lam)

print("\n=== RESUMEN FINAL ===")
for avion in sim.aviones.values():
    print(f"Avión {avion.id}: inicio={avion.minuto_inicio}, estado final={avion.estado}, aterrizaje={avion.t_aterrizaje}")
# Out:
# [t=0] Avión 1 aparece en radar (100 nm).
# [t=1] Avión 2 aparece en radar (100 nm).
# [t=2] Avión 2 reduce velocidad a 280.0 kts (congestión).
# [t=2] Avión 3 aparece en radar (100 nm).
# [t=3] Avión 2 reduce velocidad a 280.0 kts (congestión).
# [t=3] Avión 3 reduce velocidad a 260.0 kts (congestión).
# [t=3] Avión 4 aparece en radar (100 nm).
# [t=4] Avión 2 reduce velocidad a 280.0 kts (congestión).
# [t=4] Avión 3 reduce velocidad a 260.0 kts (congestión).
# [t=4] Avión 4 entra en TURNAROUND 🚨
# [t=4] Avión 5 aparece en radar (100 nm).
# [t=5] Avión 2 reduce velocidad a 280.0 kts (congestión).
# [t=5] Avión 3 reduce velocidad a 260.0 kts (congestión).
# [t=5] Avión 5 entra en TURNAROUND 🚨
# [t=5] Avión 6 aparece en radar (100 nm).
# [t=6] Avión 2 reduce velocidad a 280.0 kts (congestión).
# [t=6] Avión 3 reduce velocidad a 260.0 kts (congestión).
# [t=6] Avión 6 entra en TURNAROUND 🚨
# [t=6] Avión 7 aparece en radar (100 nm).
# ...
